# %% [markdown]
# <a href="https://colab.research.google.com/github/thdusqpf/SM-Summer-ML/blob/main/%ED%98%BC%EA%B3%B5%EB%A8%B8%EC%8B%A0_03_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('https://bit.ly/perch_csv')

# %%
df
# Out:
#     length   height   width
# 0      8.4     2.11    1.41
# 1     13.7     3.53    2.00
# 2     15.0     3.82    2.43
# 3     16.2     4.59    2.63
# 4     17.4     4.59    2.94
# 5     18.0     5.22    3.32
# 6     18.7     5.20    3.12
# 7     19.0     5.64    3.05
# 8     19.6     5.14    3.04
# 9     20.0     5.08    2.77
# 10    21.0     5.69    3.56
# 11    21.0     5.92    3.31
# 12    21.0     5.69    3.67
# 13    21.3     6.38    3.53
# 14    22.0     6.11    3.41
# 15    22.0     5.64    3.52
# 16    22.0     6.11    3.52
# 17    22.0     5.88    3.52
# 18    22.0     5.52    4.00
# 19    22.5     5.86    3.62
# 20    22.5     6.79    3.62
# 21    22.7     5.95    3.63
# 22    23.0     5.22    3.63
# 23    23.5     6.28    3.72
# 24    24.0     7.29    3.72
# 25    24.0     6.38    3.82
# 26    24.6     6.73    4.17
# 27    25.0     6.44    3.68
# 28    25.6     6.56    4.24
# 29    26.5     7.17    4.14
# 30    27.3     8.32    5.14
# 31    27.5     7.17    4.34
# ...

# %%
perch_full = df.to_numpy()
perch_full[:5]
# Out:
# array([[ 8.4 ,  2.11,  1.41],
#        [13.7 ,  3.53,  2.  ],
#        [15.  ,  3.82,  2.43],
#        [16.2 ,  4.59,  2.63],
#        [17.4 ,  4.59,  2.94]])

# %%
import numpy as np
perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(perch_full, perch_weight, random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures()
poly.fit([[2,3]]) #인터페이스를 맞추기 위한 용도
poly.transform([[2,3]])
# Out:
# array([[1., 2., 3., 4., 6., 9.]])

# %%
poly = PolynomialFeatures(include_bias = False) #bias = intercept, 결과에서 1이 빠짐
poly.fit([[2,3]])
poly.transform([[2,3]])
# Out:
# array([[2., 3., 4., 6., 9.]])

# %%
poly = PolynomialFeatures(include_bias=False)

# %%
poly.fit(train_input)
train_poly = poly.transform(train_input)
train_poly.shape
# Out:
# (42, 9)

# %%
poly.get_feature_names_out()
# Out:
# array(['x0', 'x1', 'x2', 'x0^2', 'x0 x1', 'x0 x2', 'x1^2', 'x1 x2',
#        'x2^2'], dtype=object)

# %%
test_poly = poly.transform(test_input)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(train_poly, train_target)
# Out:
# LinearRegression()

# %%
lr.score(train_poly, train_target), lr.score(test_poly, test_target)
# Out:
# (0.9903183436982125, 0.9714559911594111)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(train_poly)
train_scaled = ss.transform(train_poly)
test_scaled = ss.transform(test_poly)
